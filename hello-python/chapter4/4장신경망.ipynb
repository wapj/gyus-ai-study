# %%
sys.path.append(os.pardir)

# ipynb 파일에 있는 함수들 임포트하기 위해
import import_ipynb
import common

import sys, os
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def softmax(x):
    exp_x = np.exp(x - np.max(x))
    return exp_x / exp_x.sum()


def cross_entropy_error(y, t):
    if y.ndim == 1:
        t = t.reshape(1, t.size)
        y = y.reshape(1, y.size)

    batch_size = y.shape[0]
    return -np.sum(np.log(y[np.arange(batch_size), t])) / batch_size

# def numerical_gradient(f, x):
#     h = 1e-4
#     grad = np.zeros_like(x)

#     for idx in range(x.size):
#         tmp = x[idx]
#         x[idx] = tmp + h
#         fxh1 = f(x)

#         x[idx] = tmp - h
#         fxh2 = f(x)
#         grad[idx]  = (fxh1 - fxh2) / (2 * h)
#         x[idx] = tmp
#     return grad    

class TwoLayerNet:

    def __init__(self, input_size, hidden_size, output_size, weight_init_std=0.01):
        # 가중치 초기화
        self.params = {}
        self.params['W1'] = weight_init_std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size)
        self.params['W2'] = weight_init_std * np.random.randn(hidden_size, output_size)
        self.params['b2'] = np.zeros(output_size)


    def predict(self, x):
        W1, W2 = self.params['W1'], self.params['W2']
        b1, b2 = self.params['b1'], self.params['b2']
        a1 = np.dot(x, W1) + b1
        z1 = sigmoid(a1)
        a2 = np.dot(z1, W2) + b2
        y  = softmax(a2)
        return y

    # x : 입력 데이터, t : 정답 레이블 
    def loss(self, x, t):
        y = self.predict(x)
        return cross_entropy_error(y, t)


    def accuracy(self, x, t):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        t = np.argmax(t, axis=1)

        accuracy = np.sum(y == t) / float(x.shape[0])
        return accuracy

    def numerical_gradient(self, x, t):
        loss_W = lambda W: self.loss(x, t)

        grads = {}
        grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
        grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
        grads['W2'] = numerical_gradient(loss_W, self.params['W2'])
        grads['b2'] = numerical_gradient(loss_W, self.params['b2'])
        return grads

# %%
net = TwoLayerNet(input_size=784, hidden_size=100, output_size=10)
print(net.params['W1'].shape)
print(net.params['b1'].shape)
print(net.params['W2'].shape)
print(net.params['b2'].shape)

x = np.random.rand(100, 784)
t = np.random.rand(100, 10) 
grads = net.numerical_gradient(x, t)

print(grads['W1'].shape)
print(grads['b1'].shape)
print(grads['W2'].shape)
print(grads['b2'].shape)
# Out:
# (784, 100)
# (100,)
# (100, 10)
# (10,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 9
#       7 x = np.random.rand(100, 784)
#       8 t = np.random.rand(100, 10)
# ----> 9 grads = net.numerical_gradient(x, t)
#      11 print(grads['W1'].shape)
#      12 print(grads['b1'].shape)
#
# Cell In[23], line 79, in TwoLayerNet.numerical_gradient(self, x, t)
#      76 loss_W = lambda W: self.loss(x, t)
#      78 grads = {}
# ---> 79 grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
#      80 grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
#      81 grads['W2'] = numerical_gradient(loss_W, self.params['W2'])
#
# Cell In[19], line 33, in numerical_gradient(f, x)
#      31 tmp = x[idx]
#      32 x[idx] = tmp + h
# ---> 33 fxh1 = f(x)
#      35 x[idx] = tmp - h
#      36 fxh2 = f(x)
#
# Cell In[23], line 76, in TwoLayerNet.numerical_gradient.<locals>.<lambda>(W)
#      75 def numerical_gradient(self, x, t):
# ---> 76     loss_W = lambda W: self.loss(x, t)
#      78     grads = {}
#      79     grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
#
# Cell In[23], line 64, in TwoLayerNet.loss(self, x, t)
#      62 def loss(self, x, t):
#      63     y = self.predict(x)
# ---> 64     return cross_entropy_error(y, t)
#
# Cell In[23], line 24, in cross_entropy_error(y, t)
#      21     y = y.reshape(1, y.size)
#      23 batch_size = y.shape[0]
# ---> 24 return -np.sum(np.log(y[np.arange(batch_size), t])) / batch_size
#
# IndexError: arrays used as indices must be of integer (or boolean) type
